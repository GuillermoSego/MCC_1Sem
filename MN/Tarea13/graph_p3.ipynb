# %%
import matplotlib.pyplot as plt

# %%
# Datos de la tabla
años = [1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1920, 1921]
conejos = [30, 47.2, 70.2, 77.4, 36.3, 20.6, 18.1, 21.4, 22, 25.4, 27.1, 40.3, 57, 76.6, 52.3, 19.5, 11.2, 7.6, 14.6, 16.2, 24.7]
linces = [4, 6.1, 9.8, 35.2, 59.4, 41.7, 19, 13, 8.3, 9.1, 7.4, 8, 12.3, 19.5, 45.7, 51.1, 29.7, 15.8, 9.7, 10.1, 8.6]

# Graficar
plt.figure(figsize=(10, 6))

plt.plot(años, conejos, 'o-', label='Conejos')
plt.plot(años, linces, 's-', label='Linces')
plt.title('Población de Conejos y Linces (1900 - 1920)')
plt.xlabel('Año')
plt.ylabel('Población (en miles)')
plt.legend()
plt.grid()
plt.savefig("Problema3.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_solution(filename):
    return np.loadtxt(filename)

# Cargar soluciones
euler = load_solution("euler_results.txt")
heun = load_solution("heun_results.txt")
taylor = load_solution("taylor_results.txt")
rk4 = load_solution("rk4_results.txt")

# Graficar el plano fase
plt.figure(figsize=(10, 6))
plt.plot(euler[0], euler[1], label='Euler', marker='o')
# plt.plot(heun[0], heun[1], label='Heun', marker='x')
# plt.plot(taylor[0], taylor[1], label='Taylor', marker='^')
# plt.plot(rk4[0], rk4[1], label='RK4', marker='s')

plt.xlabel('Conejos (x)')
plt.ylabel('Linces (y)')
plt.title('Plano Fase del Sistema Depredador-Presa')
plt.legend()
plt.grid(True)
plt.savefig("Euler_orbita.pdf")
plt.show()
